# %% [markdown]
# # Model:
#
# - Model: MesoNet + LSTMM
# - Paper: https://arxiv.org/html/2412.06643v1 (Only MesoNet)

# %%
from google.colab import drive
import pandas as pd
import os

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Set metadata path
csv_path = "/content/drive/MyDrive/Dataset-3/global_metadata_cleaned.csv"

# Step 3: Load CSV
df = pd.read_csv(csv_path)

# Step 4: Base folder path (where FF and DFDC folders are stored)
base_path = "/content/drive/MyDrive/Dataset-3"

# Step 5: Check if each file exists
missing_files = []

for i, row in df.iterrows():
    full_path = os.path.join(base_path, row['file_path'])
    if not os.path.exists(full_path):
        missing_files.append(full_path)

# Step 6: Print summary
print(f"Checked {len(df)} files.")
print(f"Missing {len(missing_files)} files.")

# Step 7: Optional: Save missing files to a text file
with open("/content/missing_files.txt", "w") as f:
    for path in missing_files:
        f.write(f"{path}\n")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Checked 5281 files.
# Missing 0 files.

# %%
# !nvidia-smi
# !pip install torch torchvision tqdm matplotlib seaborn scikit-learn opencv-python
# Out:
# Wed May 21 19:00:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
"""
MesoNet + LSTM Architecture for Deepfake Detection using PyTorch
Optimized for Google Colab A100 GPU
"""

import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import datetime
import time
import random
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from collections import defaultdict

# PyTorch imports
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch.cuda.amp import autocast, GradScaler

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# For reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed()

# Global configs
BATCH_SIZE = 16
NUM_WORKERS = 4
FRAME_COUNT = 20  # Number of frames to extract from each video
IMAGE_SIZE = 128  # MesoNet typically uses 256x256, but smaller for faster training
LEARNING_RATE = 3e-4
NUM_EPOCHS = 30
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

##############################################
# Model Architecture: MesoNet + LSTM
##############################################

class MesoNet(nn.Module):
    """
    Implementation of MesoNet model for deepfake detection
    """
    def __init__(self):
        super(MesoNet, self).__init__()

        # First conv block
        self.conv1 = nn.Conv2d(3, 8, 3, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(8)
        self.pool1 = nn.MaxPool2d(2, 2)

        # Second conv block
        self.conv2 = nn.Conv2d(8, 16, 3, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(16)
        self.pool2 = nn.MaxPool2d(2, 2)

        # Third conv block
        self.conv3 = nn.Conv2d(16, 32, 3, padding=1, bias=False)
        self.bn3 = nn.BatchNorm2d(32)
        self.pool3 = nn.MaxPool2d(2, 2)

        # Fourth conv block
        self.conv4 = nn.Conv2d(32, 64, 3, padding=1, bias=False)
        self.bn4 = nn.BatchNorm2d(64)
        self.pool4 = nn.MaxPool2d(2, 2)

        # Calculate feature dim based on input size
        feature_dim = 64 * (IMAGE_SIZE // 16) * (IMAGE_SIZE // 16)

        # Feature size after convolution
        self.feature_size = feature_dim

    def forward(self, x):
        # First block
        x = self.pool1(F.relu(self.bn1(self.conv1(x))))

        # Second block
        x = self.pool2(F.relu(self.bn2(self.conv2(x))))

        # Third block
        x = self.pool3(F.relu(self.bn3(self.conv3(x))))

        # Fourth block
        x = self.pool4(F.relu(self.bn4(self.conv4(x))))

        return x


class MesoNetLSTM(nn.Module):
    """
    Combined MesoNet + LSTM model for sequential frame analysis
    """
    def __init__(self, lstm_hidden_size=128, lstm_layers=2, dropout=0.5):
        super(MesoNetLSTM, self).__init__()

        # MesoNet base model for feature extraction
        self.mesonet = MesoNet()

        # Feature dim calculated from MesoNet's output
        feature_dim = self.mesonet.feature_size

        # Flatten features for LSTM input
        self.flatten = nn.Flatten()

        # LSTM layer
        self.lstm = nn.LSTM(
            input_size=feature_dim,
            hidden_size=lstm_hidden_size,
            num_layers=lstm_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout if lstm_layers > 1 else 0
        )

        # Final classification layers
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(lstm_hidden_size * 2, 64)  # *2 for bidirectional
        self.fc2 = nn.Linear(64, 1)

    def forward(self, x):
        # x shape: [batch, frames, channels, height, width]
        batch_size, seq_len = x.size(0), x.size(1)

        # Process each frame through MesoNet to extract features
        frame_features = []
        for t in range(seq_len):
            frame = x[:, t, :, :, :]  # Get frame at time t
            features = self.mesonet(frame)  # Extract features
            features = self.flatten(features)  # Flatten for LSTM
            frame_features.append(features)

        # Stack features for LSTM
        lstm_input = torch.stack(frame_features, dim=1)  # [batch, seq_len, features]

        # Process through LSTM
        lstm_out, _ = self.lstm(lstm_input)

        # Take only the output from the last time step
        lstm_out = lstm_out[:, -1, :]

        # Final classification
        x = self.dropout(lstm_out)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x  # Raw logits for BCEWithLogitsLoss


##############################################
# Data Processing
##############################################

def extract_frames(video_path, num_frames=FRAME_COUNT):
    """Extract frames from a video file"""
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return None

    frames = []
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if frame_count <= 0:
        print(f"Error: No frames in video {video_path}")
        return None

    # Calculate frame indices to extract (evenly distributed)
    indices = np.linspace(0, frame_count - 1, num_frames, dtype=int)

    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()

        if ret:
            # Convert to RGB (from BGR)
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            # Resize frame
            frame = cv2.resize(frame, (IMAGE_SIZE, IMAGE_SIZE))

            frames.append(frame)

    cap.release()

    # If we couldn't extract enough frames, repeat the last frame
    while len(frames) < num_frames:
        if len(frames) > 0:
            frames.append(frames[-1])
        else:
            # Create an empty black frame if no frames were extracted
            frames.append(np.zeros((IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.uint8))

    return np.array(frames)


class DeepfakeDataset(Dataset):
    """PyTorch Dataset for deepfake videos"""
    def __init__(self, df, base_path, transform=None, preload=False):
        self.df = df
        self.base_path = base_path
        self.transform = transform
        self.preload = preload
        self.frames_cache = {}

        # Preload frames if enabled
        if preload:
            for idx in tqdm(range(len(df)), desc="Preloading frames"):
                video_path = os.path.join(base_path, df.iloc[idx]['file_path'])
                self.frames_cache[idx] = extract_frames(video_path)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # Get frames
        if idx in self.frames_cache:
            frames = self.frames_cache[idx]
        else:
            video_path = os.path.join(self.base_path, self.df.iloc[idx]['file_path'])
            frames = extract_frames(video_path)

            if frames is None:
                # Return empty frames if extraction failed
                frames = np.zeros((FRAME_COUNT, IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.uint8)

        # Apply transforms
        if self.transform:
            transformed_frames = []
            for frame in frames:
                transformed_frames.append(self.transform(frame))
            frames = torch.stack(transformed_frames)

        # Get label
        label = 1 if self.df.iloc[idx]['label'] == 'FAKE' else 0

        return frames, torch.tensor([label], dtype=torch.float32)


##############################################
# Training and Evaluation Functions
##############################################

def train_epoch(model, dataloader, criterion, optimizer, device, scaler):
    """Train for one epoch"""
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    # Progress bar
    pbar = tqdm(dataloader, desc="Training")

    for frames, labels in pbar:
        # Move data to device
        frames = frames.to(device)
        labels = labels.to(device)

        # Zero gradients
        optimizer.zero_grad()

        # Forward pass with mixed precision
        with autocast():
            outputs = model(frames)
            loss = criterion(outputs, labels)

        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Update statistics
        running_loss += loss.item() * frames.size(0)
        predicted = (torch.sigmoid(outputs) > 0.5).float()
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Update progress bar
        pbar.set_postfix({'loss': loss.item(), 'acc': correct/total})

    epoch_loss = running_loss / total
    epoch_acc = correct / total

    return epoch_loss, epoch_acc


def evaluate(model, dataloader, criterion, device):
    """Evaluate model on validation data"""
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for frames, labels in tqdm(dataloader, desc="Evaluating"):
            # Move data to device
            frames = frames.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(frames)
            loss = criterion(outputs, labels)

            # Update statistics
            running_loss += loss.item() * frames.size(0)
            predicted = (outputs > 0.5).float()
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            # Store predictions and labels for metrics
            all_preds.extend(outputs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    epoch_loss = running_loss / total
    epoch_acc = correct / total

    return epoch_loss, epoch_acc, np.array(all_preds), np.array(all_labels)


def train_model(model, train_loader, val_loader, criterion, optimizer,
                scheduler, device, num_epochs, model_save_path):
    """Complete training process with tracking metrics"""
    best_val_acc = 0.0
    history = {
        'train_loss': [], 'train_acc': [],
        'val_loss': [], 'val_acc': []
    }

    # Create a gradient scaler for mixed precision training
    scaler = GradScaler()

    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch+1}/{num_epochs}")
        print('-' * 30)

        # Train
        train_loss, train_acc = train_epoch(model, train_loader, criterion,
                                           optimizer, device, scaler)

        # Evaluate
        val_loss, val_acc, val_preds, val_labels = evaluate(model, val_loader,
                                                          criterion, device)

        # Update learning rate
        scheduler.step(val_loss)

        # Print metrics
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
        print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

        # Update history
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        # Save model if better than previous best
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            print(f"New best validation accuracy: {val_acc:.4f}")
            torch.save(model.state_dict(), model_save_path)
            print(f"Model saved to {model_save_path}")

    return history


##############################################
# Visualization Functions
##############################################

def plot_metrics(history, title):
    """Plot training and validation metrics"""
    plt.figure(figsize=(12, 4))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history['train_acc'], label='Training Accuracy')
    plt.plot(history['val_acc'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history['train_loss'], label='Training Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.savefig(f'{title}_metrics.png')
    plt.show()


def plot_confusion_matrix(y_true, y_pred, title):
    """Plot confusion matrix"""
    # Convert probabilities to binary predictions
    y_pred_binary = (np.array(y_pred) > 0.5).astype(int)
    y_true = np.array(y_true).astype(int)

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred_binary)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'{title} - Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.xticks([0.5, 1.5], ['Real', 'Fake'])
    plt.yticks([0.5, 1.5], ['Real', 'Fake'])
    plt.tight_layout()
    plt.savefig(f'{title}_confusion_matrix.png')
    plt.show()

    # Print classification report
    print(f"\nClassification Report for {title}:")
    target_names = ['Real', 'Fake']
    print(classification_report(y_true, y_pred_binary, target_names=target_names))


def plot_roc_curve(y_true, y_score, title):
    """Plot ROC curve"""
    y_true = np.array(y_true).astype(int)
    y_score = np.array(y_score)

    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.3f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{title} - ROC Curve')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'{title}_roc_curve.png')
    plt.show()


##############################################
# Main Execution
##############################################

def main():
    # Set paths
    base_path = "/content/drive/MyDrive/Dataset-3"
    csv_path = os.path.join(base_path, "global_metadata_cleaned.csv")
    models_path = os.path.join(base_path, "models")

    # Create models directory if it doesn't exist
    os.makedirs(models_path, exist_ok=True)

    # Load metadata
    print("Loading metadata...")
    df = pd.read_csv(csv_path)

    # Data transforms
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Training with each dataset separately and then combined
    for dataset_config in [
        {'name': 'DFDC', 'datasets': ['DFDC']},
        {'name': 'FF', 'datasets': ['FF']},
        {'name': 'Combined', 'datasets': ['DFDC', 'FF']}
    ]:
        print(f"\n{'='*50}")
        print(f"Training on {dataset_config['name']} dataset")
        print(f"{'='*50}")

        # Filter data
        dataset_df = df[df['dataset'].isin(dataset_config['datasets'])]
        print(f"Total samples: {len(dataset_df)}")

        # Split train/test
        train_df = dataset_df[dataset_df['subset'] == 'train']
        test_df = dataset_df[dataset_df['subset'] == 'test']
        print(f"Train samples: {len(train_df)}, Test samples: {len(test_df)}")

        # Create datasets
        print("Creating datasets...")
        train_dataset = DeepfakeDataset(train_df, base_path, transform=transform)
        test_dataset = DeepfakeDataset(test_df, base_path, transform=transform)

        # Create dataloaders
        train_loader = DataLoader(
            train_dataset,
            batch_size=BATCH_SIZE,
            shuffle=True,
            num_workers=NUM_WORKERS,
            pin_memory=True
        )

        test_loader = DataLoader(
            test_dataset,
            batch_size=BATCH_SIZE,
            shuffle=False,
            num_workers=NUM_WORKERS,
            pin_memory=True
        )

        # Initialize model
        print("Initializing model...")
        model = MesoNetLSTM().to(DEVICE)
        print(f"Model on device: {DEVICE}")

        # Loss function and optimizer
        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='min', factor=0.5, patience=3, verbose=True
        )

        # Model save path
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        model_save_path = os.path.join(models_path, f"mesonet_lstm_{dataset_config['name']}_{timestamp}.pth")

        # Train model
        print("Starting training...")
        history = train_model(
            model, train_loader, test_loader, criterion, optimizer,
            scheduler, DEVICE, NUM_EPOCHS, model_save_path
        )

        # Load best model for evaluation
        print("Loading best model for evaluation...")
        model.load_state_dict(torch.load(model_save_path))

        # Evaluate on test set
        _, test_acc, test_preds, test_labels = evaluate(model, test_loader, criterion, DEVICE)
        print(f"\nFinal Test Accuracy: {test_acc:.4f}")

        # Plot metrics
        plot_metrics(history, f"{dataset_config['name']}_model")

        # Plot confusion matrix
        plot_confusion_matrix(test_labels, test_preds, f"{dataset_config['name']}_model")

        # Plot ROC curve
        plot_roc_curve(test_labels, test_preds, f"{dataset_config['name']}_model")

        print(f"\nTraining and evaluation completed for {dataset_config['name']} dataset")
        print(f"Best model saved to {model_save_path}")


if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading metadata...
#
# ==================================================
# Training on DFDC dataset
# ==================================================
# Total samples: 3293
# Train samples: 2633, Test samples: 660
# Creating datasets...
# Initializing model...
# Model on device: cuda
# Starting training...
#
# Epoch 1/30
# ------------------------------
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# <ipython-input-4-72519a590dbd>:350: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# <ipython-input-4-72519a590dbd>:280: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.6819 | Train Acc: 0.5526
# Val Loss: 0.6616 | Val Acc: 0.5242
# New best validation accuracy: 0.5242
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 2/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.6485 | Train Acc: 0.6301
# Val Loss: 0.6359 | Val Acc: 0.6242
# New best validation accuracy: 0.6242
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 3/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.6304 | Train Acc: 0.6540
# Val Loss: 0.6221 | Val Acc: 0.6667
# New best validation accuracy: 0.6667
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 4/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.6093 | Train Acc: 0.6738
# Val Loss: 0.5896 | Val Acc: 0.6864
# New best validation accuracy: 0.6864
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 5/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.5894 | Train Acc: 0.6889
# Val Loss: 0.5832 | Val Acc: 0.6591
#
# Epoch 6/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.5709 | Train Acc: 0.6996
# Val Loss: 0.5468 | Val Acc: 0.7061
# New best validation accuracy: 0.7061
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 7/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.5579 | Train Acc: 0.7117
# Val Loss: 0.5538 | Val Acc: 0.6879
#
# Epoch 8/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.5364 | Train Acc: 0.7224
# Val Loss: 0.5408 | Val Acc: 0.7273
# New best validation accuracy: 0.7273
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 9/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.5234 | Train Acc: 0.7372
# Val Loss: 0.5413 | Val Acc: 0.7273
#
# Epoch 10/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.5044 | Train Acc: 0.7531
# Val Loss: 0.5586 | Val Acc: 0.6758
#
# Epoch 11/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.4868 | Train Acc: 0.7676
# Val Loss: 0.5774 | Val Acc: 0.7227
#
# Epoch 12/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.4708 | Train Acc: 0.7767
# Val Loss: 0.5175 | Val Acc: 0.7773
# New best validation accuracy: 0.7773
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 13/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.4500 | Train Acc: 0.7828
# Val Loss: 0.6363 | Val Acc: 0.6348
#
# Epoch 14/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.4309 | Train Acc: 0.7942
# Val Loss: 0.5037 | Val Acc: 0.7379
#
# Epoch 15/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.4352 | Train Acc: 0.8025
# Val Loss: 0.4695 | Val Acc: 0.7561
#
# Epoch 16/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.4018 | Train Acc: 0.8169
# Val Loss: 0.4687 | Val Acc: 0.7500
#
# Epoch 17/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.3974 | Train Acc: 0.8150
# Val Loss: 0.5286 | Val Acc: 0.7879
# New best validation accuracy: 0.7879
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 18/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.3975 | Train Acc: 0.8219
# Val Loss: 0.5076 | Val Acc: 0.7545
#
# Epoch 19/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.3608 | Train Acc: 0.8367
# Val Loss: 0.4497 | Val Acc: 0.7864
#
# Epoch 20/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.3424 | Train Acc: 0.8507
# Val Loss: 0.5409 | Val Acc: 0.7742
#
# Epoch 21/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.3407 | Train Acc: 0.8549
# Val Loss: 0.4452 | Val Acc: 0.7970
# New best validation accuracy: 0.7970
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 22/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.3210 | Train Acc: 0.8568
# Val Loss: 0.4579 | Val Acc: 0.8182
# New best validation accuracy: 0.8182
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 23/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.3159 | Train Acc: 0.8648
# Val Loss: 0.4348 | Val Acc: 0.7909
#
# Epoch 24/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.2945 | Train Acc: 0.8769
# Val Loss: 0.4542 | Val Acc: 0.7970
#
# Epoch 25/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.2847 | Train Acc: 0.8731
# Val Loss: 0.5105 | Val Acc: 0.7818
#
# Epoch 26/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.2696 | Train Acc: 0.8887
# Val Loss: 0.6051 | Val Acc: 0.8030
#
# Epoch 27/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.2671 | Train Acc: 0.8826
# Val Loss: 0.5208 | Val Acc: 0.7955
#
# Epoch 28/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.2173 | Train Acc: 0.9062
# Val Loss: 0.5122 | Val Acc: 0.8182
#
# Epoch 29/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.1834 | Train Acc: 0.9240
# Val Loss: 0.4830 | Val Acc: 0.8303
# New best validation accuracy: 0.8303
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# Epoch 30/30
# ------------------------------
# Training:   0%|          | 0/165 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Train Loss: 0.1933 | Train Acc: 0.9183
# Val Loss: 0.5517 | Val Acc: 0.8182
# Loading best model for evaluation...
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
# Final Test Accuracy: 0.8303
# Classification Report for DFDC_model:
#               precision    recall  f1-score   support
#
#         Real       0.82      0.87      0.84       346
#         Fake       0.85      0.79      0.82       314
#
#     accuracy                           0.83       660
#    macro avg       0.83      0.83      0.83       660
# weighted avg       0.83      0.83      0.83       660
# Training and evaluation completed for DFDC dataset
# Best model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_DFDC_20250521_190436.pth
#
# ==================================================
# Training on FF dataset
# ==================================================
# Total samples: 1988
# Train samples: 1591, Test samples: 397
# Creating datasets...
# Initializing model...
# Model on device: cuda
# Starting training...
#
# Epoch 1/30
# ------------------------------
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# <ipython-input-4-72519a590dbd>:350: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# <ipython-input-4-72519a590dbd>:280: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.6948 | Train Acc: 0.4909
# Val Loss: 0.6922 | Val Acc: 0.4987
# New best validation accuracy: 0.4987
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 2/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.6921 | Train Acc: 0.5110
# Val Loss: 0.6891 | Val Acc: 0.4987
#
# Epoch 3/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.6888 | Train Acc: 0.5405
# Val Loss: 0.6798 | Val Acc: 0.4987
#
# Epoch 4/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.6667 | Train Acc: 0.6003
# Val Loss: 0.6139 | Val Acc: 0.6146
# New best validation accuracy: 0.6146
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 5/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.6343 | Train Acc: 0.6367
# Val Loss: 0.6044 | Val Acc: 0.6877
# New best validation accuracy: 0.6877
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 6/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.5908 | Train Acc: 0.6983
# Val Loss: 0.6180 | Val Acc: 0.6952
# New best validation accuracy: 0.6952
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 7/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.6073 | Train Acc: 0.6945
# Val Loss: 0.5415 | Val Acc: 0.7456
# New best validation accuracy: 0.7456
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 8/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.5430 | Train Acc: 0.7335
# Val Loss: 0.4929 | Val Acc: 0.7531
# New best validation accuracy: 0.7531
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 9/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.5104 | Train Acc: 0.7498
# Val Loss: 0.4393 | Val Acc: 0.8136
# New best validation accuracy: 0.8136
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 10/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.4300 | Train Acc: 0.8114
# Val Loss: 0.4128 | Val Acc: 0.8136
#
# Epoch 11/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.3966 | Train Acc: 0.8328
# Val Loss: 0.4848 | Val Acc: 0.7683
#
# Epoch 12/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.3736 | Train Acc: 0.8366
# Val Loss: 0.3532 | Val Acc: 0.8463
# New best validation accuracy: 0.8463
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 13/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.2898 | Train Acc: 0.8850
# Val Loss: 0.4238 | Val Acc: 0.8489
# New best validation accuracy: 0.8489
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 14/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.3066 | Train Acc: 0.8693
# Val Loss: 0.3258 | Val Acc: 0.8564
# New best validation accuracy: 0.8564
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 15/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.2531 | Train Acc: 0.8975
# Val Loss: 0.3835 | Val Acc: 0.8665
# New best validation accuracy: 0.8665
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 16/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.2131 | Train Acc: 0.9164
# Val Loss: 0.4498 | Val Acc: 0.8035
#
# Epoch 17/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.2272 | Train Acc: 0.9126
# Val Loss: 0.4158 | Val Acc: 0.8363
#
# Epoch 18/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.1805 | Train Acc: 0.9340
# Val Loss: 0.3655 | Val Acc: 0.8514
#
# Epoch 19/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.1291 | Train Acc: 0.9573
# Val Loss: 0.3447 | Val Acc: 0.8766
# New best validation accuracy: 0.8766
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 20/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0991 | Train Acc: 0.9661
# Val Loss: 0.3846 | Val Acc: 0.8841
# New best validation accuracy: 0.8841
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 21/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0948 | Train Acc: 0.9730
# Val Loss: 0.4187 | Val Acc: 0.8791
#
# Epoch 22/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0873 | Train Acc: 0.9679
# Val Loss: 0.4071 | Val Acc: 0.8892
# New best validation accuracy: 0.8892
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 23/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0499 | Train Acc: 0.9830
# Val Loss: 0.4451 | Val Acc: 0.8866
#
# Epoch 24/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0520 | Train Acc: 0.9837
# Val Loss: 0.4621 | Val Acc: 0.8866
#
# Epoch 25/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0421 | Train Acc: 0.9855
# Val Loss: 0.5155 | Val Acc: 0.8791
#
# Epoch 26/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0330 | Train Acc: 0.9893
# Val Loss: 0.5424 | Val Acc: 0.8791
#
# Epoch 27/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0351 | Train Acc: 0.9887
# Val Loss: 0.4830 | Val Acc: 0.8892
#
# Epoch 28/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0308 | Train Acc: 0.9912
# Val Loss: 0.5283 | Val Acc: 0.8766
#
# Epoch 29/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0224 | Train Acc: 0.9937
# Val Loss: 0.4940 | Val Acc: 0.8917
# New best validation accuracy: 0.8917
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# Epoch 30/30
# ------------------------------
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Train Loss: 0.0268 | Train Acc: 0.9918
# Val Loss: 0.4652 | Val Acc: 0.8992
# New best validation accuracy: 0.8992
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
# Loading best model for evaluation...
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
# Final Test Accuracy: 0.8992
# Classification Report for FF_model:
#               precision    recall  f1-score   support
#
#         Real       0.91      0.89      0.90       198
#         Fake       0.89      0.91      0.90       199
#
#     accuracy                           0.90       397
#    macro avg       0.90      0.90      0.90       397
# weighted avg       0.90      0.90      0.90       397
# Training and evaluation completed for FF dataset
# Best model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_FF_20250521_192442.pth
#
# ==================================================
# Training on Combined dataset
# ==================================================
# Total samples: 5281
# Train samples: 4224, Test samples: 1057
# Creating datasets...
# Initializing model...
# Model on device: cuda
# Starting training...
#
# Epoch 1/30
# ------------------------------
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# <ipython-input-4-72519a590dbd>:350: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# <ipython-input-4-72519a590dbd>:280: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.6862 | Train Acc: 0.5516
# Val Loss: 0.6662 | Val Acc: 0.5147
# New best validation accuracy: 0.5147
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 2/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.6659 | Train Acc: 0.5947
# Val Loss: 0.6481 | Val Acc: 0.6291
# New best validation accuracy: 0.6291
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 3/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.6546 | Train Acc: 0.6174
# Val Loss: 0.6321 | Val Acc: 0.6064
#
# Epoch 4/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.6326 | Train Acc: 0.6439
# Val Loss: 0.6172 | Val Acc: 0.6235
#
# Epoch 5/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.6164 | Train Acc: 0.6683
# Val Loss: 0.5958 | Val Acc: 0.7039
# New best validation accuracy: 0.7039
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 6/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.5950 | Train Acc: 0.6832
# Val Loss: 0.6043 | Val Acc: 0.6925
#
# Epoch 7/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.5723 | Train Acc: 0.7027
# Val Loss: 0.6183 | Val Acc: 0.6793
#
# Epoch 8/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.5477 | Train Acc: 0.7228
# Val Loss: 0.5593 | Val Acc: 0.6660
#
# Epoch 9/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.5291 | Train Acc: 0.7370
# Val Loss: 0.5401 | Val Acc: 0.7379
# New best validation accuracy: 0.7379
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 10/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.5057 | Train Acc: 0.7609
# Val Loss: 0.5138 | Val Acc: 0.7465
# New best validation accuracy: 0.7465
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 11/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.4934 | Train Acc: 0.7685
# Val Loss: 0.5196 | Val Acc: 0.7181
#
# Epoch 12/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.4740 | Train Acc: 0.7746
# Val Loss: 0.4904 | Val Acc: 0.7663
# New best validation accuracy: 0.7663
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 13/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.4465 | Train Acc: 0.7988
# Val Loss: 0.4898 | Val Acc: 0.7606
#
# Epoch 14/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.4287 | Train Acc: 0.7995
# Val Loss: 0.5297 | Val Acc: 0.7512
#
# Epoch 15/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.4258 | Train Acc: 0.8042
# Val Loss: 0.5176 | Val Acc: 0.7408
#
# Epoch 16/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.3925 | Train Acc: 0.8262
# Val Loss: 0.4963 | Val Acc: 0.7654
#
# Epoch 17/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.3720 | Train Acc: 0.8378
# Val Loss: 0.5427 | Val Acc: 0.7692
# New best validation accuracy: 0.7692
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 18/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.3343 | Train Acc: 0.8542
# Val Loss: 0.4827 | Val Acc: 0.7815
# New best validation accuracy: 0.7815
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 19/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.3055 | Train Acc: 0.8736
# Val Loss: 0.4701 | Val Acc: 0.7947
# New best validation accuracy: 0.7947
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 20/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.2873 | Train Acc: 0.8764
# Val Loss: 0.5320 | Val Acc: 0.8061
# New best validation accuracy: 0.8061
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 21/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.2790 | Train Acc: 0.8816
# Val Loss: 0.4664 | Val Acc: 0.8023
#
# Epoch 22/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.2634 | Train Acc: 0.8883
# Val Loss: 0.5142 | Val Acc: 0.8079
# New best validation accuracy: 0.8079
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 23/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.2536 | Train Acc: 0.8946
# Val Loss: 0.4972 | Val Acc: 0.7975
#
# Epoch 24/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.2442 | Train Acc: 0.8932
# Val Loss: 0.4946 | Val Acc: 0.7985
#
# Epoch 25/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.2228 | Train Acc: 0.9072
# Val Loss: 0.5431 | Val Acc: 0.8070
#
# Epoch 26/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.1917 | Train Acc: 0.9190
# Val Loss: 0.5232 | Val Acc: 0.8098
# New best validation accuracy: 0.8098
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 27/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.1733 | Train Acc: 0.9273
# Val Loss: 0.5528 | Val Acc: 0.8231
# New best validation accuracy: 0.8231
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 28/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.1687 | Train Acc: 0.9323
# Val Loss: 0.5780 | Val Acc: 0.8221
#
# Epoch 29/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.1624 | Train Acc: 0.9323
# Val Loss: 0.5256 | Val Acc: 0.8288
# New best validation accuracy: 0.8288
# Model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
#
# Epoch 30/30
# ------------------------------
# Training:   0%|          | 0/264 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Train Loss: 0.1384 | Train Acc: 0.9458
# Val Loss: 0.6203 | Val Acc: 0.8184
# Loading best model for evaluation...
# Evaluating:   0%|          | 0/67 [00:00<?, ?it/s]
# Final Test Accuracy: 0.8288
# Classification Report for Combined_model:
#               precision    recall  f1-score   support
#
#         Real       0.81      0.86      0.84       544
#         Fake       0.85      0.79      0.82       513
#
#     accuracy                           0.83      1057
#    macro avg       0.83      0.83      0.83      1057
# weighted avg       0.83      0.83      0.83      1057
# Training and evaluation completed for Combined dataset
# Best model saved to /content/drive/MyDrive/Dataset-3/models/mesonet_lstm_Combined_20250521_193735.pth
